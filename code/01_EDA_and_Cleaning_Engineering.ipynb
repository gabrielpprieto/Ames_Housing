# %% [markdown]
# # Ames Housing Data and Kaggle Challenge
# > ## EDA and Data Cleaning
# >> Gabriel Perez Prieto

# %% [markdown]
# #### Importing Libraries

# %%
# libraries import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# plot style to be used
plt.style.use('seaborn-whitegrid')

# %%
# setting max columns limit
pd.options.display.max_columns = 500
pd.options.display.max_rows = 100

# %% [markdown]
# #### Loading Data

# %%
# reading train dataset into memmory
df = pd.read_csv('../datasets/train.csv')

# %% [markdown]
# #### Data Cleaning

# %%
# checking the shape of the dataframe
df.shape
# Out:
# (2051, 81)

# %%
# printing the first 5 rows
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
# changing the column names to lower and underscore
df.columns = [column.lower().replace(' ','_') for column in df.columns]

# %%
# checking all columns of the dataframe
df.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#        'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#        'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#        'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#        'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#        'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#        'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#        'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#        '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#        'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#        'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
#        'fireplaces', 'fireplace_qu', 'garage_type', 'garage_yr_blt',
#        'garage_finish', 'garage_cars', 'garage_area', 'garage_qual',
#        'garage_cond', 'paved_drive', 'wood_deck_sf', 'open_porch_sf',
#        'enclosed_porch', '3ssn_porch', 'screen_porch', 'pool_area', 'pool_qc',
#        'fence', 'misc_feature', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type',
#        'saleprice'],
#       dtype='object')

# %% [markdown]
# #### Handling Null Values

# %%
# checking for null values
df.isnull().mean()[df.isnull().mean() > 0].sort_values(ascending=False)
# Out:
# pool_qc           0.995612
# misc_feature      0.968308
# alley             0.931741
# fence             0.804973
# fireplace_qu      0.487567
# lot_frontage      0.160897
# garage_yr_blt     0.055583
# garage_cond       0.055583
# garage_qual       0.055583
# garage_finish     0.055583
# garage_type       0.055095
# bsmt_exposure     0.028279
# bsmtfin_type_2    0.027304
# bsmt_cond         0.026816
# bsmt_qual         0.026816
# bsmtfin_type_1    0.026816
# mas_vnr_type      0.010726
# mas_vnr_area      0.010726
# bsmt_half_bath    0.000975
# bsmt_full_bath    0.000975
# garage_cars       0.000488
# bsmtfin_sf_1      0.000488
# bsmtfin_sf_2      0.000488
# bsmt_unf_sf       0.000488
# garage_area       0.000488
# total_bsmt_sf     0.000488
# dtype: float64

# %%
# transform columns to numerical - This will fix some null values as well!

qualitative_to_numeric_dict = {'pool_qc': {'Ex': 5, 
                                           'Gd': 4,
                                           'TA': 3,
                                           'Fa': 2,
                                            np.nan: 0},
                               'misc_feature': {'Elev': 5,
                                                'Gar2': 4,
                                                'Othr': 3,
                                                'Shed': 2,
                                                'TenC': 1,
                                                 np.nan: 0},
                               'alley': {'Grvl': 2,
                                         'Pave': 1,
                                          np.nan: 0},
                               'fence': {'GdPrv': 4,
                                         'MnPrv': 3,
                                         'GdWo': 2,
                                         'MnWw': 1,
                                          np.nan: 0},
                               'fireplace_qu': {'Ex': 5, 
                                                'Gd': 4,
                                                'TA': 3,
                                                'Fa': 2,
                                                'Po': 1,
                                                 np.nan: 0},
                               'garage_cond': {'Ex': 5, 
                                               'Gd': 4,
                                               'TA': 3,
                                               'Fa': 2,
                                               'Po': 1,
                                                np.nan: 0},
                               'garage_qual': {'Ex': 5, 
                                               'Gd': 4,
                                               'TA': 3,
                                               'Fa': 2,
                                               'Po': 1,
                                                np.nan: 0},
                               'garage_finish': {'Fin': 3,
                                                 'RFn': 2,
                                                 'Unf': 1,
                                                 np.nan: 0},
                               'garage_type': {'2Types': 6,
                                               'Attchd': 5,
                                               'Basment': 4,
                                               'BuiltIn': 3,
                                               'CarPort': 2,
                                               'Detchd': 1,
                                                np.nan: 0},
                               'bsmt_exposure': {'Gd': 4,
                                                 'Av': 3,
                                                 'Mn': 2,
                                                 'No': 1,
                                                  np.nan: 0},
                               'bsmtfin_type_2': {'GLQ': 6,
                                                  'ALQ': 5,
                                                  'BLQ': 4,
                                                  'Rec': 3,
                                                  'LwQ': 2,
                                                  'Unf': 1,
                                                   np.nan: 0},
                               'bsmt_cond': {'Ex': 5, 
                                             'Gd': 4,
                                             'TA': 3,
                                             'Fa': 2,
                                             'Po': 1,
                                              np.nan: 0},
                               'bsmt_qual': {'Ex': 5, 
                                             'Gd': 4,
                                             'TA': 3,
                                             'Fa': 2,
                                             'Po': 1,
                                              np.nan: 0},
                               'bsmtfin_type_1': {'GLQ': 6,
                                                  'ALQ': 5,
                                                  'BLQ': 4,
                                                  'Rec': 3,
                                                  'LwQ': 2,
                                                  'Unf': 1,
                                                   np.nan: 0},
                               'mas_vnr_type': {'BrkCmn': 4,
                                                'BrkFace': 3,
                                                'CBlock': 2,
                                                'None': 0,
                                                 np.nan: 0,
                                                'Stone': 1},
                               'exter_qual': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'exter_cond': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'heating_qc': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'central_air': {'Y': 1, 
                                               'N': 0},
                               'kitchen_qual': {'Ex': 5, 
                                                'Gd': 4,
                                                'TA': 3,
                                                'Fa': 2,
                                                'Po': 1},
                               'electrical': {'SBrkr': 4,
                                              'FuseA': 3,
                                              'FuseF': 2,
                                              'FuseP': 1,
                                              'Mix': 0}
                              }

# %%
# replace qualitative values by a range of integers
df.replace(qualitative_to_numeric_dict, inplace=True)

# %%
# checking for null columns again as see what is left
df.isnull().mean()[df.isnull().mean() > 0].sort_values(ascending=False)
# Out:
# lot_frontage      0.160897
# garage_yr_blt     0.055583
# mas_vnr_area      0.010726
# bsmt_half_bath    0.000975
# bsmt_full_bath    0.000975
# garage_area       0.000488
# garage_cars       0.000488
# total_bsmt_sf     0.000488
# bsmt_unf_sf       0.000488
# bsmtfin_sf_2      0.000488
# bsmtfin_sf_1      0.000488
# dtype: float64

# %% [markdown]
# #### Filling NaN

# %%
# list of columns with null values
null_columns = [column for column in df.columns if df[column].isnull().sum() > 0]

# %%
#adding salesprice columns to check correlations between possible features and target variable
null_columns.append('saleprice')

# %%
# checking correlation of null_columns with target variable 'saleprice'
df[null_columns].corr()['saleprice'].sort_values(ascending=False)
# Out:
# saleprice         1.000000
# garage_area       0.650270
# garage_cars       0.648220
# total_bsmt_sf     0.628925
# garage_yr_blt     0.533922
# mas_vnr_area      0.512230
# bsmtfin_sf_1      0.423519
# lot_frontage      0.341842
# bsmt_full_bath    0.283662
# bsmt_unf_sf       0.190210
# bsmtfin_sf_2      0.016255
# bsmt_half_bath   -0.045328
# Name: saleprice, dtype: float64

# %%
# fill null values with 0 for columns with lower correlation with 'saleprice'
df['bsmtfin_sf_1'].fillna(0, inplace=True)
df['bsmtfin_sf_2'].fillna(0, inplace=True)
df['bsmt_unf_sf'].fillna(0, inplace=True)
df['total_bsmt_sf'].fillna(0, inplace=True)
df['garage_cars'].fillna(0, inplace=True)
df['garage_area'].fillna(0, inplace=True)
df['bsmt_full_bath'].fillna(0, inplace=True)
df['bsmt_half_bath'].fillna(0, inplace=True)

# fill null values with the mean() for columns with higher correlation with 'saleprice'
df['mas_vnr_area'].fillna(df['mas_vnr_area'].median(), inplace=True)
df['garage_yr_blt'].fillna(df['garage_yr_blt'].median(), inplace=True)
df['lot_frontage'].fillna(df['lot_frontage'].median(), inplace=True)

# %%
# checking variable types
df.dtypes.head()
# Out:
# id                int64
# pid               int64
# ms_subclass       int64
# ms_zoning        object
# lot_frontage    float64
# dtype: object

# %%
# checking for duplicated values
df.duplicated().mean()
# Out:
# 0.0

# %% [markdown]
# ### EDA ( Exploratory Data Analysis )

# %%
df['saleprice'].median()
# Out:
# 162500.0

# %%
# plotting distribution of sale price
plt.figure(figsize=(8,6))
# df['saleprice'].hist()
plt.hist(df['saleprice'], bins=10)
plt.title('Distribution of House Price', size=18, pad=10)
plt.xlabel('Sale Price', size=12)
plt.ylabel('Frequency', size=12)
plt.axvline(df['saleprice'].mean(), color='red')
plt.axvline(df['saleprice'].median(), color='black');

# %%
# define numerical and nominal columns
numerical_variables = df.select_dtypes(include='number')
nominal_variables = df.select_dtypes(exclude='number')

# %%
# convert to integers nominal variables that were transformed into numerical
for var in nominal_variables.columns.values:
    try:
        df[var] = df[var].astype(int)
    except:
        continue

# redefine numerical and nominal columns
numerical_variables = df.select_dtypes(include='number')
nominal_variables = df.select_dtypes(exclude='number')

# %%
# correlations with target variable ['saleprice']
correlations_saleprice = df.corr()[['saleprice']].abs().sort_values(['saleprice'], ascending=False)

# %%
# creating a list with column names for columns with correlation > .5 with ['saleprice']
strong_correlations = correlations_saleprice.loc[correlations_saleprice['saleprice'] >= .5][1:].index.values

# %%
# printing numerical variables with strong_correlation with ['saleprice'] 
strong_correlations
# Out:
# array(['overall_qual', 'exter_qual', 'gr_liv_area', 'kitchen_qual',
#        'garage_area', 'garage_cars', 'total_bsmt_sf', '1st_flr_sf',
#        'bsmt_qual', 'year_built', 'garage_finish', 'year_remod/add',
#        'fireplace_qu', 'full_bath', 'garage_yr_blt', 'totrms_abvgrd',
#        'mas_vnr_area'], dtype=object)

# %%
# creating a heatmap for the most relevant correlations with saleprice

plt.figure(figsize=(17,7))
sns.heatmap(correlations_saleprice.loc[correlations_saleprice['saleprice'] >= .5][1:],
            annot=True, annot_kws={"size": 13}, cmap='coolwarm', vmin=-1, vmax=1)
plt.yticks(size=13)
plt.xticks(size=13)
plt.title('Heatmap - Most Relevant Correlations with Sale Price', size=16, pad=10);

# %% [markdown]
# #### Scatterplots of  Variables with Strong Correlation with Saleprice

# %%
# creating scatterplots for numerical variables with ['saleprice']
nrows=int(np.ceil((len(strong_correlations))/2))
fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize= (12, 2.5 * len(strong_correlations)))

plt.tight_layout(pad=4)
ax = ax.ravel() 
for index, column in enumerate(strong_correlations):
    sns.scatterplot(x = df[column], y = df['saleprice'], ax=ax[index]) 
    ax[index].set_title(strong_correlations[index], size=14)
    ax[index].set_xlabel(strong_correlations[index], size=13)
    ax[index].set_ylabel('saleprice', size=13);

# %% [markdown]
# #### Chcecking Outliers - From Scatterplots

# %%
df.loc[df['gr_liv_area'] > 5000]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 960       0       IR3          Bnk    AllPub     Corner        Gtl
# 1885      0       IR1          Bnk    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
#      exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 960        Stucco       Stucco             1         796.0           5
# 1885      CemntBd      CmentBd             1        1224.0           5
#
#       exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 960            3      PConc          5          3              4
# 1885           3      PConc          5          3              4
#
#       bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 960                6        5644.0               1           0.0        466.0
# 1885               6        4010.0               1           0.0       1085.0
#
#       total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 960          6110.0    GasA           5            1           4        4692
# 1885         5095.0    GasA           5            1           4        5095
#
#       2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 960          950                0         5642             2.0
# 1885           0                0         5095             1.0
#
#       bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 960              0.0          2          1              3              1
# 1885             1.0          2          1              2              1
#
#       kitchen_qual  totrms_abvgrd functional  fireplaces  fireplace_qu  \
# 960              5             12        Typ           3             4
# 1885             5             15        Typ           2             4
#
#       garage_type  garage_yr_blt  garage_finish  garage_cars  garage_area  \
# 960             5         2008.0              3          2.0       1418.0
# 1885            5         2008.0              3          3.0       1154.0
#
#       garage_qual  garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 960             3            3           Y           214            292
# 1885            3            3           Y           546            484
#
#       enclosed_porch  3ssn_porch  screen_porch  pool_area  pool_qc  fence  \
# 960                0           0             0        480        4      0
# 1885               0           0             0          0        0      0
#
#       misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 960              0         0        1     2008       New     160000
# 1885             5     17000       10     2007       New     183850

# %%
df.loc[df['garage_cars'] == 5]
# Out:
#       id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 925  747  903236040           30        RM          50.0      8635   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 925      0       Reg          Lvl    AllPub     Inside        Gtl
#
#     neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 925      BrkSide        Norm        Norm      1Fam      1Story             5
#
#      overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 925             5        1925            1950        Hip   CompShg
#
#     exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 925      Wd Sdng      Wd Sdng             0           0.0           3
#
#      exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 925           2     BrkTil          3          3              1
#
#      bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 925               2         134.0               1           0.0        938.0
#
#      total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 925         1072.0    GasA           3            1           4        1072
#
#      2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  \
# 925           0                0         1072             1.0             0.0
#
#      full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  kitchen_qual  \
# 925          1          0              2              1             3
#
#      totrms_abvgrd functional  fireplaces  fireplace_qu  garage_type  \
# 925              5        Typ           0             0            1
#
#      garage_yr_blt  garage_finish  garage_cars  garage_area  garage_qual  \
# 925         1982.0              1          5.0       1184.0            2
#
#      garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 925            3           P             0              0             105
#
#      3ssn_porch  screen_porch  pool_area  pool_qc  fence  misc_feature  \
# 925           0             0          0        0      0             0
#
#      misc_val  mo_sold  yr_sold sale_type  saleprice
# 925         0        8     2009       WD      126500

# %%
df.loc[df['total_bsmt_sf'] > 5000]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 960       0       IR3          Bnk    AllPub     Corner        Gtl
# 1885      0       IR1          Bnk    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
#      exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 960        Stucco       Stucco             1         796.0           5
# 1885      CemntBd      CmentBd             1        1224.0           5
#
#       exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 960            3      PConc          5          3              4
# 1885           3      PConc          5          3              4
#
#       bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 960                6        5644.0               1           0.0        466.0
# 1885               6        4010.0               1           0.0       1085.0
#
#       total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 960          6110.0    GasA           5            1           4        4692
# 1885         5095.0    GasA           5            1           4        5095
#
#       2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 960          950                0         5642             2.0
# 1885           0                0         5095             1.0
#
#       bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 960              0.0          2          1              3              1
# 1885             1.0          2          1              2              1
#
#       kitchen_qual  totrms_abvgrd functional  fireplaces  fireplace_qu  \
# 960              5             12        Typ           3             4
# 1885             5             15        Typ           2             4
#
#       garage_type  garage_yr_blt  garage_finish  garage_cars  garage_area  \
# 960             5         2008.0              3          2.0       1418.0
# 1885            5         2008.0              3          3.0       1154.0
#
#       garage_qual  garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 960             3            3           Y           214            292
# 1885            3            3           Y           546            484
#
#       enclosed_porch  3ssn_porch  screen_porch  pool_area  pool_qc  fence  \
# 960                0           0             0        480        4      0
# 1885               0           0             0          0        0      0
#
#       misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 960              0         0        1     2008       New     160000
# 1885             5     17000       10     2007       New     183850

# %%
df.loc[df['1st_flr_sf'] > 3000]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 328   1773  528366050           20        RL          68.0     12692   Pave
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 328       0       IR1          Lvl    AllPub     Inside        Gtl
# 616       0       IR1          Lvl    AllPub     Inside        Gtl
# 960       0       IR3          Bnk    AllPub     Corner        Gtl
# 1885      0       IR1          Bnk    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 328       NoRidge        Norm        Norm      1Fam      1Story             8
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 328              5        1992            1993        Hip   CompShg
# 616              7        1959            1996      Gable   CompShg
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
#      exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 328       BrkFace      BrkFace             0           0.0           4
# 616       Plywood      Plywood             0           0.0           3
# 960        Stucco       Stucco             1         796.0           5
# 1885      CemntBd      CmentBd             1        1224.0           5
#
#       exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 328            3      PConc          4          3              1
# 616            3       Slab          0          0              0
# 960            3      PConc          5          3              4
# 1885           3      PConc          5          3              4
#
#       bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 328                6        1231.0               1           0.0       1969.0
# 616                0           0.0               0           0.0          0.0
# 960                6        5644.0               1           0.0        466.0
# 1885               6        4010.0               1           0.0       1085.0
#
#       total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 328          3200.0    GasA           5            1           4        3228
# 616             0.0    GasA           3            1           4        3820
# 960          6110.0    GasA           5            1           4        4692
# 1885         5095.0    GasA           5            1           4        5095
#
#       2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 328            0                0         3228             1.0
# 616            0                0         3820             0.0
# 960          950                0         5642             2.0
# 1885           0                0         5095             1.0
#
#       bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 328              0.0          3          0              4              1
# 616              0.0          3          1              5              1
# 960              0.0          2          1              3              1
# 1885             1.0          2          1              2              1
#
#       kitchen_qual  totrms_abvgrd functional  fireplaces  fireplace_qu  \
# 328              4             10        Typ           1             4
# 616              5             11        Typ           2             4
# 960              5             12        Typ           3             4
# 1885             5             15        Typ           2             4
#
#       garage_type  garage_yr_blt  garage_finish  garage_cars  garage_area  \
# 328             5         1992.0              2          2.0        546.0
# 616             5         1959.0              1          2.0        624.0
# 960             5         2008.0              3          2.0       1418.0
# 1885            5         2008.0              3          3.0       1154.0
#
#       garage_qual  garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 328             3            3           Y           264             75
# 616             3            3           Y             0            372
# 960             3            3           Y           214            292
# 1885            3            3           Y           546            484
#
#       enclosed_porch  3ssn_porch  screen_porch  pool_area  pool_qc  fence  \
# 328              291           0             0          0        0      0
# 616                0           0             0          0        0      0
# 960                0           0             0        480        4      0
# 1885               0           0             0          0        0      0
#
#       misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 328              0         0        5     2007       WD      430000
# 616              0         0        7     2008       WD      284700
# 960              0         0        1     2008       New     160000
# 1885             5     17000       10     2007       New     183850

# %%
df.loc[df['garage_yr_blt'] > 2200]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1699  2261  916384070           20        RL          68.0      8298   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 1699      0       IR1          HLS    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1699       Timber        Norm        Norm      1Fam      1Story             8
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1699             5        2006            2007        Hip   CompShg
#
#      exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 1699      VinylSd      VinylSd             0           0.0           4
#
#       exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 1699           3      PConc          4          3              3
#
#       bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 1699               6         583.0               1           0.0        963.0
#
#       total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 1699         1546.0    GasA           5            1           4        1564
#
#       2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1699           0                0         1564             0.0
#
#       bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1699             0.0          2          0              2              1
#
#       kitchen_qual  totrms_abvgrd functional  fireplaces  fireplace_qu  \
# 1699             5              6        Typ           1             4
#
#       garage_type  garage_yr_blt  garage_finish  garage_cars  garage_area  \
# 1699            5         2207.0              2          2.0        502.0
#
#       garage_qual  garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 1699            3            3           Y           132              0
#
#       enclosed_porch  3ssn_porch  screen_porch  pool_area  pool_qc  fence  \
# 1699               0           0             0          0        0      0
#
#       misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1699             0         0        9     2007       New     267300

# %%
df.loc[df['mas_vnr_area'] > 1500]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1409  1850  533241030           60        FV          66.0      7399   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 1409      1       IR1          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1409      Somerst        Norm        Norm      1Fam      2Story             7
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1409             5        1997            1998        Hip   CompShg
#
#      exterior_1st exterior_2nd  mas_vnr_type  mas_vnr_area  exter_qual  \
# 1409      VinylSd      VinylSd             3        1600.0           4
#
#       exter_cond foundation  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 1409           3      PConc          4          3              1
#
#       bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 1409               4         649.0               1           0.0        326.0
#
#       total_bsmt_sf heating  heating_qc  central_air  electrical  1st_flr_sf  \
# 1409          975.0    GasA           5            1           4         975
#
#       2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1409         975                0         1950             0.0
#
#       bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1409             0.0          2          1              3              1
#
#       kitchen_qual  totrms_abvgrd functional  fireplaces  fireplace_qu  \
# 1409             4              7        Typ           1             3
#
#       garage_type  garage_yr_blt  garage_finish  garage_cars  garage_area  \
# 1409            1         1997.0              2          2.0        576.0
#
#       garage_qual  garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 1409            3            3           Y             0             10
#
#       enclosed_porch  3ssn_porch  screen_porch  pool_area  pool_qc  fence  \
# 1409               0           0           198          0        0      0
#
#       misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1409             0         0        6     2007       WD      239000

# %%
# dropping outliers
rows_to_drop = [960, 1885, 925, 328, 616, 1699, 1409]
for row in rows_to_drop:
    df.drop(row, inplace=True)

# %% [markdown]
# #### Histograms for Numerical Variables

# %%
# plotting histograms for every numerical column - checking distributions
df.hist(figsize=(15,15));

# %% [markdown]
# #### Correlation Amongst Strong Correlated Variables ( With SalePrice ) - Look for Possible Interaction Terms

# %%
# plotting heatmap to look for possible interaction terms

# create a figure
plt.figure(figsize=(14,10))

# correlations data
corr = df[strong_correlations].corr()

# Set up mask so triangle at the top is white
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Set title
plt.title('Correlations Heatmap - Strong Correlation Variables',fontsize=18)

# create heatmap
sns.heatmap(corr, mask=mask, square=True, annot=True, cmap='coolwarm', vmin=-1, vmax=1);

# Adapted from https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# #### Creating Interaction Terms Between Strongly Correlated Variables
# > ##### Correlation > .7

# %%
# creating df['garage_area * garage_cars']
df['garage_area * garage_cars'] = df['garage_area'] * df['garage_cars']

# creating df['totrms_abvgrd * gr_liv_area']
df['totrms_abvgrd * gr_liv_area'] = df['totrms_abvgrd'] * df['gr_liv_area']

# creating df['1st_flr_sf * total_bsmt_sf']
df['1st_flr_sf * total_bsmt_sf'] = df['1st_flr_sf'] * df['total_bsmt_sf']

# creating df['garage_yr_blt * year_built']
df['garage_yr_blt * year_built'] = df['garage_yr_blt'] * df['year_built']

# %% [markdown]
# #### Creating Interaction Terms For Other Variables
# > ##### Criteria: Create a total sq_ft for the house

# %%
# creating df['total_area']
df['total_area'] = df['total_bsmt_sf'] + df['1st_flr_sf'] + df['2nd_flr_sf'] \
                   + df['gr_liv_area'] + df['garage_area']

# %% [markdown]
# > ##### Criteria: Polynomial Features

# %%
# preprocessing for polynomial features for numerical variables
features = numerical_variables.columns
X = df[features]
X.head()
# Out:
#     id        pid  ms_subclass  lot_frontage  lot_area  alley  overall_qual  \
# 0  109  533352170           60          68.0     13517      0             6
# 1  544  531379050           60          43.0     11492      0             7
# 2  153  535304180           20          68.0      7922      0             5
# 3  318  916386060           60          73.0      9802      0             5
# 4  255  906425045           50          82.0     14235      0             6
#
#    overall_cond  year_built  year_remod/add  mas_vnr_type  mas_vnr_area  \
# 0             8        1976            2005             3         289.0
# 1             5        1996            1997             3         132.0
# 2             7        1953            2007             0           0.0
# 3             5        2006            2007             0           0.0
# 4             8        1900            1993             0           0.0
#
#    exter_qual  exter_cond  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 0           4           3          3          3              1
# 1           4           3          4          3              1
# 2           3           4          3          3              1
# 3           3           3          4          3              1
# 4           3           3          2          4              1
#
#    bsmtfin_type_1  bsmtfin_sf_1  bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 0               6         533.0               1           0.0        192.0
# 1               6         637.0               1           0.0        276.0
# 2               6         731.0               1           0.0        326.0
# 3               1           0.0               1           0.0        384.0
# 4               1           0.0               1           0.0        676.0
#
#    total_bsmt_sf  heating_qc  central_air  electrical  1st_flr_sf  2nd_flr_sf  \
# 0          725.0           5            1           4         725         754
# 1          913.0           5            1           4         913        1209
# 2         1057.0           3            1           4        1057           0
# 3          384.0           4            1           4         744         700
# 4          676.0           3            1           4         831         614
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 0                0         1479             0.0             0.0          2
# 1                0         2122             1.0             0.0          2
# 2                0         1057             1.0             0.0          1
# 3                0         1444             0.0             0.0          2
# 4                0         1445             0.0             0.0          2
#
#    half_bath  bedroom_abvgr  kitchen_abvgr  kitchen_qual  totrms_abvgrd  \
# 0          1              3              1             4              6
# 1          1              4              1             4              8
# 2          0              3              1             4              5
# 3          1              3              1             3              7
# 4          0              3              1             3              6
#
#    fireplaces  fireplace_qu  garage_type  garage_yr_blt  garage_finish  \
# 0           0             0            5         1976.0              2
# 1           1             3            5         1997.0              2
# 2           0             0            1         1953.0              1
# 3           0             0            3         2007.0              3
# 4           0             0            1         1957.0              1
#
#    garage_cars  garage_area  garage_qual  garage_cond  wood_deck_sf  \
# 0          2.0        475.0            3            3             0
# 1          2.0        559.0            3            3             0
# 2          1.0        246.0            3            3             0
# 3          2.0        400.0            3            3           100
# 4          2.0        484.0            3            3             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 0             44               0           0             0          0
# 1             74               0           0             0          0
# 2             52               0           0             0          0
# 3              0               0           0             0          0
# 4             59               0           0             0          0
#
#    pool_qc  fence  misc_feature  misc_val  mo_sold  yr_sold  saleprice
# 0        0      0             0         0        3     2010     130500
# 1        0      0             0         0        4     2009     220000
# 2        0      0             0         0        1     2010     109000
# 3        0      0             0         0        4     2010     174000
# 4        0      0             0         0        3     2010     138500

# %%
# instantiate PolynomialFeatures
poly = PolynomialFeatures(include_bias=False)

# %%
# create X_poly
X_poly = poly.fit_transform(X)
X_poly.shape
# Out:
# (2044, 1890)

# %%
# feature names created
poly.get_feature_names(features)
# Out:
# ['id',
#  'pid',
#  'ms_subclass',
#  'lot_frontage',
#  'lot_area',
#  'alley',
#  'overall_qual',
#  'overall_cond',
#  'year_built',
#  'year_remod/add',
#  'mas_vnr_type',
#  'mas_vnr_area',
#  'exter_qual',
#  'exter_cond',
#  'bsmt_qual',
#  'bsmt_cond',
#  'bsmt_exposure',
#  'bsmtfin_type_1',
#  'bsmtfin_sf_1',
#  'bsmtfin_type_2',
#  'bsmtfin_sf_2',
#  'bsmt_unf_sf',
#  'total_bsmt_sf',
#  'heating_qc',
#  'central_air',
#  'electrical',
#  '1st_flr_sf',
#  '2nd_flr_sf',
#  'low_qual_fin_sf',
#  'gr_liv_area',
#  'bsmt_full_bath',
#  'bsmt_half_bath',
#  'full_bath',
#  'half_bath',
#  'bedroom_abvgr',
#  'kitchen_abvgr',
#  'kitchen_qual',
#  'totrms_abvgrd',
#  'fireplaces',
#  'fireplace_qu',
#  'garage_type',
#  'garage_yr_blt',
#  'garage_finish',
#  'garage_cars',
#  'garage_area',
#  'garage_qual',
#  'garage_cond',
#  'wood_deck_sf',
#  'open_porch_sf',
#  'enclosed_porch',
#  '3ssn_porch',
#  'screen_porch',
#  'pool_area',
#  'pool_qc',
#  'fence',
#  'misc_feature',
#  'misc_val',
#  'mo_sold',
#  'yr_sold',
#  'saleprice',
#  'id^2',
#  'id pid',
#  'id ms_subclass',
#  'id lot_frontage',
#  'id lot_area',
#  'id alley',
#  'id overall_qual',
#  'id overall_cond',
#  'id year_built',
#  'id year_remod/add',
#  'id mas_vnr_type',
#  'id mas_vnr_area',
#  'id exter_qual',
#  'id exter_cond',
#  'id bsmt_qual',
#  'id bsmt_cond',
#  'id bsmt_exposure',
#  'id bsmtfin_type_1',
#  'id bsmtfin_sf_1',
#  'id bsmtfin_type_2',
#  'id bsmtfin_sf_2',
#  'id bsmt_unf_sf',
#  'id total_bsmt_sf',
#  'id heating_qc',
#  'id central_air',
#  'id electrical',
#  'id 1st_flr_sf',
#  'id 2nd_flr_sf',
#  'id low_qual_fin_sf',
#  'id gr_liv_area',
#  'id bsmt_full_bath',
#  'id bsmt_half_bath',
#  'id full_bath',
#  'id half_bath',
#  'id bedroom_abvgr',
#  'id kitchen_abvgr',
#  'id kitchen_qual',
#  'id totrms_abvgrd',
#  'id fireplaces',
#  'id fireplace_qu',
#  'id garage_type',
#  'id garage_yr_blt',
#  'id garage_finish',
#  'id garage_cars',
#  'id garage_area',
#  'id garage_qual',
#  'id garage_cond',
#  'id wood_deck_sf',
#  'id open_porch_sf',
#  'id enclosed_porch',
#  'id 3ssn_porch',
#  'id screen_porch',
#  'id pool_area',
#  'id pool_qc',
#  'id fence',
#  'id misc_feature',
#  'id misc_val',
#  'id mo_sold',
#  'id yr_sold',
#  'id saleprice',
#  'pid^2',
#  'pid ms_subclass',
#  'pid lot_frontage',
#  'pid lot_area',
#  'pid alley',
#  'pid overall_qual',
#  'pid overall_cond',
#  'pid year_built',
#  'pid year_remod/add',
#  'pid mas_vnr_type',
#  'pid mas_vnr_area',
#  'pid exter_qual',
#  'pid exter_cond',
#  'pid bsmt_qual',
#  'pid bsmt_cond',
#  'pid bsmt_exposure',
#  'pid bsmtfin_type_1',
#  'pid bsmtfin_sf_1',
#  'pid bsmtfin_type_2',
#  'pid bsmtfin_sf_2',
#  'pid bsmt_unf_sf',
#  'pid total_bsmt_sf',
#  'pid heating_qc',
#  'pid central_air',
#  'pid electrical',
#  'pid 1st_flr_sf',
#  'pid 2nd_flr_sf',
#  'pid low_qual_fin_sf',
#  'pid gr_liv_area',
#  'pid bsmt_full_bath',
#  'pid bsmt_half_bath',
#  'pid full_bath',
#  'pid half_bath',
#  'pid bedroom_abvgr',
#  'pid kitchen_abvgr',
#  'pid kitchen_qual',
#  'pid totrms_abvgrd',
#  'pid fireplaces',
#  'pid fireplace_qu',
#  'pid garage_type',
#  'pid garage_yr_blt',
#  'pid garage_finish',
#  'pid garage_cars',
#  'pid garage_area',
#  'pid garage_qual',
#  'pid garage_cond',
#  'pid wood_deck_sf',
#  'pid open_porch_sf',
#  'pid enclosed_porch',
#  'pid 3ssn_porch',
#  'pid screen_porch',
#  'pid pool_area',
#  'pid pool_qc',
#  'pid fence',
#  'pid misc_feature',
#  'pid misc_val',
#  'pid mo_sold',
#  'pid yr_sold',
#  'pid saleprice',
#  'ms_subclass^2',
#  'ms_subclass lot_frontage',
#  'ms_subclass lot_area',
#  'ms_subclass alley',
#  'ms_subclass overall_qual',
#  'ms_subclass overall_cond',
#  'ms_subclass year_built',
#  'ms_subclass year_remod/add',
#  'ms_subclass mas_vnr_type',
#  'ms_subclass mas_vnr_area',
#  'ms_subclass exter_qual',
#  'ms_subclass exter_cond',
#  'ms_subclass bsmt_qual',
#  'ms_subclass bsmt_cond',
#  'ms_subclass bsmt_exposure',
#  'ms_subclass bsmtfin_type_1',
#  'ms_subclass bsmtfin_sf_1',
#  'ms_subclass bsmtfin_type_2',
#  'ms_subclass bsmtfin_sf_2',
#  'ms_subclass bsmt_unf_sf',
#  'ms_subclass total_bsmt_sf',
#  'ms_subclass heating_qc',
#  'ms_subclass central_air',
#  'ms_subclass electrical',
#  'ms_subclass 1st_flr_sf',
#  'ms_subclass 2nd_flr_sf',
#  'ms_subclass low_qual_fin_sf',
#  'ms_subclass gr_liv_area',
#  'ms_subclass bsmt_full_bath',
#  'ms_subclass bsmt_half_bath',
#  'ms_subclass full_bath',
#  'ms_subclass half_bath',
#  'ms_subclass bedroom_abvgr',
#  'ms_subclass kitchen_abvgr',
#  'ms_subclass kitchen_qual',
#  'ms_subclass totrms_abvgrd',
#  'ms_subclass fireplaces',
#  'ms_subclass fireplace_qu',
#  'ms_subclass garage_type',
#  'ms_subclass garage_yr_blt',
#  'ms_subclass garage_finish',
#  'ms_subclass garage_cars',
#  'ms_subclass garage_area',
#  'ms_subclass garage_qual',
#  'ms_subclass garage_cond',
#  'ms_subclass wood_deck_sf',
#  'ms_subclass open_porch_sf',
#  'ms_subclass enclosed_porch',
#  'ms_subclass 3ssn_porch',
#  'ms_subclass screen_porch',
#  'ms_subclass pool_area',
#  'ms_subclass pool_qc',
#  'ms_subclass fence',
#  'ms_subclass misc_feature',
#  'ms_subclass misc_val',
#  'ms_subclass mo_sold',
#  'ms_subclass yr_sold',
#  'ms_subclass saleprice',
#  'lot_frontage^2',
#  'lot_frontage lot_area',
#  'lot_frontage alley',
#  'lot_frontage overall_qual',
#  'lot_frontage overall_cond',
#  'lot_frontage year_built',
#  'lot_frontage year_remod/add',
#  'lot_frontage mas_vnr_type',
#  'lot_frontage mas_vnr_area',
#  'lot_frontage exter_qual',
#  'lot_frontage exter_cond',
#  'lot_frontage bsmt_qual',
#  'lot_frontage bsmt_cond',
#  'lot_frontage bsmt_exposure',
#  'lot_frontage bsmtfin_type_1',
#  'lot_frontage bsmtfin_sf_1',
#  'lot_frontage bsmtfin_type_2',
#  'lot_frontage bsmtfin_sf_2',
#  'lot_frontage bsmt_unf_sf',
#  'lot_frontage total_bsmt_sf',
#  'lot_frontage heating_qc',
#  'lot_frontage central_air',
#  'lot_frontage electrical',
#  'lot_frontage 1st_flr_sf',
#  'lot_frontage 2nd_flr_sf',
#  'lot_frontage low_qual_fin_sf',
#  'lot_frontage gr_liv_area',
#  'lot_frontage bsmt_full_bath',
#  'lot_frontage bsmt_half_bath',
#  'lot_frontage full_bath',
#  'lot_frontage half_bath',
#  'lot_frontage bedroom_abvgr',
#  'lot_frontage kitchen_abvgr',
#  'lot_frontage kitchen_qual',
#  'lot_frontage totrms_abvgrd',
#  'lot_frontage fireplaces',
#  'lot_frontage fireplace_qu',
#  'lot_frontage garage_type',
#  'lot_frontage garage_yr_blt',
#  'lot_frontage garage_finish',
#  'lot_frontage garage_cars',
#  'lot_frontage garage_area',
#  'lot_frontage garage_qual',
#  'lot_frontage garage_cond',
#  'lot_frontage wood_deck_sf',
#  'lot_frontage open_porch_sf',
#  'lot_frontage enclosed_porch',
#  'lot_frontage 3ssn_porch',
#  'lot_frontage screen_porch',
#  'lot_frontage pool_area',
#  'lot_frontage pool_qc',
#  'lot_frontage fence',
#  'lot_frontage misc_feature',
#  'lot_frontage misc_val',
#  'lot_frontage mo_sold',
#  'lot_frontage yr_sold',
#  'lot_frontage saleprice',
#  'lot_area^2',
#  'lot_area alley',
#  'lot_area overall_qual',
#  'lot_area overall_cond',
#  'lot_area year_built',
#  'lot_area year_remod/add',
#  'lot_area mas_vnr_type',
#  'lot_area mas_vnr_area',
#  'lot_area exter_qual',
#  'lot_area exter_cond',
#  'lot_area bsmt_qual',
#  'lot_area bsmt_cond',
#  'lot_area bsmt_exposure',
#  'lot_area bsmtfin_type_1',
#  'lot_area bsmtfin_sf_1',
#  'lot_area bsmtfin_type_2',
#  'lot_area bsmtfin_sf_2',
#  'lot_area bsmt_unf_sf',
#  'lot_area total_bsmt_sf',
#  'lot_area heating_qc',
#  'lot_area central_air',
#  'lot_area electrical',
#  'lot_area 1st_flr_sf',
#  'lot_area 2nd_flr_sf',
#  'lot_area low_qual_fin_sf',
#  'lot_area gr_liv_area',
#  'lot_area bsmt_full_bath',
#  'lot_area bsmt_half_bath',
#  'lot_area full_bath',
#  'lot_area half_bath',
#  'lot_area bedroom_abvgr',
#  'lot_area kitchen_abvgr',
#  'lot_area kitchen_qual',
#  'lot_area totrms_abvgrd',
#  'lot_area fireplaces',
#  'lot_area fireplace_qu',
#  'lot_area garage_type',
#  'lot_area garage_yr_blt',
#  'lot_area garage_finish',
#  'lot_area garage_cars',
#  'lot_area garage_area',
#  'lot_area garage_qual',
#  'lot_area garage_cond',
#  'lot_area wood_deck_sf',
#  'lot_area open_porch_sf',
#  'lot_area enclosed_porch',
#  'lot_area 3ssn_porch',
#  'lot_area screen_porch',
#  'lot_area pool_area',
#  'lot_area pool_qc',
#  'lot_area fence',
#  'lot_area misc_feature',
#  'lot_area misc_val',
#  'lot_area mo_sold',
#  'lot_area yr_sold',
#  'lot_area saleprice',
#  'alley^2',
#  'alley overall_qual',
#  'alley overall_cond',
#  'alley year_built',
#  'alley year_remod/add',
#  'alley mas_vnr_type',
#  'alley mas_vnr_area',
#  'alley exter_qual',
#  'alley exter_cond',
#  'alley bsmt_qual',
#  'alley bsmt_cond',
#  'alley bsmt_exposure',
#  'alley bsmtfin_type_1',
#  'alley bsmtfin_sf_1',
#  'alley bsmtfin_type_2',
#  'alley bsmtfin_sf_2',
#  'alley bsmt_unf_sf',
#  'alley total_bsmt_sf',
#  'alley heating_qc',
#  'alley central_air',
#  'alley electrical',
#  'alley 1st_flr_sf',
#  'alley 2nd_flr_sf',
#  'alley low_qual_fin_sf',
#  'alley gr_liv_area',
#  'alley bsmt_full_bath',
#  'alley bsmt_half_bath',
#  'alley full_bath',
#  'alley half_bath',
#  'alley bedroom_abvgr',
#  'alley kitchen_abvgr',
#  'alley kitchen_qual',
#  'alley totrms_abvgrd',
#  'alley fireplaces',
#  'alley fireplace_qu',
#  'alley garage_type',
#  'alley garage_yr_blt',
#  'alley garage_finish',
#  'alley garage_cars',
#  'alley garage_area',
#  'alley garage_qual',
#  'alley garage_cond',
#  'alley wood_deck_sf',
#  'alley open_porch_sf',
#  'alley enclosed_porch',
#  'alley 3ssn_porch',
#  'alley screen_porch',
#  'alley pool_area',
#  'alley pool_qc',
#  'alley fence',
#  'alley misc_feature',
#  'alley misc_val',
#  'alley mo_sold',
#  'alley yr_sold',
#  'alley saleprice',
#  'overall_qual^2',
#  'overall_qual overall_cond',
#  'overall_qual year_built',
#  'overall_qual year_remod/add',
#  'overall_qual mas_vnr_type',
#  'overall_qual mas_vnr_area',
#  'overall_qual exter_qual',
#  'overall_qual exter_cond',
#  'overall_qual bsmt_qual',
#  'overall_qual bsmt_cond',
#  'overall_qual bsmt_exposure',
#  'overall_qual bsmtfin_type_1',
#  'overall_qual bsmtfin_sf_1',
#  'overall_qual bsmtfin_type_2',
#  'overall_qual bsmtfin_sf_2',
#  'overall_qual bsmt_unf_sf',
#  'overall_qual total_bsmt_sf',
#  'overall_qual heating_qc',
#  'overall_qual central_air',
#  'overall_qual electrical',
#  'overall_qual 1st_flr_sf',
#  'overall_qual 2nd_flr_sf',
#  'overall_qual low_qual_fin_sf',
#  'overall_qual gr_liv_area',
#  'overall_qual bsmt_full_bath',
#  'overall_qual bsmt_half_bath',
#  'overall_qual full_bath',
#  'overall_qual half_bath',
#  'overall_qual bedroom_abvgr',
#  'overall_qual kitchen_abvgr',
#  'overall_qual kitchen_qual',
#  'overall_qual totrms_abvgrd',
#  'overall_qual fireplaces',
#  'overall_qual fireplace_qu',
#  'overall_qual garage_type',
#  'overall_qual garage_yr_blt',
#  'overall_qual garage_finish',
#  'overall_qual garage_cars',
#  'overall_qual garage_area',
#  'overall_qual garage_qual',
#  'overall_qual garage_cond',
#  'overall_qual wood_deck_sf',
#  'overall_qual open_porch_sf',
#  'overall_qual enclosed_porch',
#  'overall_qual 3ssn_porch',
#  'overall_qual screen_porch',
#  'overall_qual pool_area',
#  'overall_qual pool_qc',
#  'overall_qual fence',
#  'overall_qual misc_feature',
#  'overall_qual misc_val',
#  'overall_qual mo_sold',
#  'overall_qual yr_sold',
#  'overall_qual saleprice',
#  'overall_cond^2',
#  'overall_cond year_built',
#  'overall_cond year_remod/add',
#  'overall_cond mas_vnr_type',
#  'overall_cond mas_vnr_area',
#  'overall_cond exter_qual',
#  'overall_cond exter_cond',
#  'overall_cond bsmt_qual',
#  'overall_cond bsmt_cond',
#  'overall_cond bsmt_exposure',
#  'overall_cond bsmtfin_type_1',
#  'overall_cond bsmtfin_sf_1',
#  'overall_cond bsmtfin_type_2',
#  'overall_cond bsmtfin_sf_2',
#  'overall_cond bsmt_unf_sf',
#  'overall_cond total_bsmt_sf',
#  'overall_cond heating_qc',
#  'overall_cond central_air',
#  'overall_cond electrical',
#  'overall_cond 1st_flr_sf',
#  'overall_cond 2nd_flr_sf',
#  'overall_cond low_qual_fin_sf',
#  'overall_cond gr_liv_area',
#  'overall_cond bsmt_full_bath',
#  'overall_cond bsmt_half_bath',
#  'overall_cond full_bath',
#  'overall_cond half_bath',
#  'overall_cond bedroom_abvgr',
#  'overall_cond kitchen_abvgr',
#  'overall_cond kitchen_qual',
#  'overall_cond totrms_abvgrd',
#  'overall_cond fireplaces',
#  'overall_cond fireplace_qu',
#  'overall_cond garage_type',
#  'overall_cond garage_yr_blt',
#  'overall_cond garage_finish',
#  'overall_cond garage_cars',
#  'overall_cond garage_area',
#  'overall_cond garage_qual',
#  'overall_cond garage_cond',
#  'overall_cond wood_deck_sf',
#  'overall_cond open_porch_sf',
#  'overall_cond enclosed_porch',
#  'overall_cond 3ssn_porch',
#  'overall_cond screen_porch',
#  'overall_cond pool_area',
#  'overall_cond pool_qc',
#  'overall_cond fence',
#  'overall_cond misc_feature',
#  'overall_cond misc_val',
#  'overall_cond mo_sold',
#  'overall_cond yr_sold',
#  'overall_cond saleprice',
#  'year_built^2',
#  'year_built year_remod/add',
#  'year_built mas_vnr_type',
#  'year_built mas_vnr_area',
#  'year_built exter_qual',
#  'year_built exter_cond',
#  'year_built bsmt_qual',
#  'year_built bsmt_cond',
#  'year_built bsmt_exposure',
#  'year_built bsmtfin_type_1',
#  'year_built bsmtfin_sf_1',
#  'year_built bsmtfin_type_2',
#  'year_built bsmtfin_sf_2',
#  'year_built bsmt_unf_sf',
#  'year_built total_bsmt_sf',
#  'year_built heating_qc',
#  'year_built central_air',
#  'year_built electrical',
#  'year_built 1st_flr_sf',
#  'year_built 2nd_flr_sf',
#  'year_built low_qual_fin_sf',
#  'year_built gr_liv_area',
#  'year_built bsmt_full_bath',
#  'year_built bsmt_half_bath',
#  'year_built full_bath',
#  'year_built half_bath',
#  'year_built bedroom_abvgr',
#  'year_built kitchen_abvgr',
#  'year_built kitchen_qual',
#  'year_built totrms_abvgrd',
#  'year_built fireplaces',
#  'year_built fireplace_qu',
#  'year_built garage_type',
#  'year_built garage_yr_blt',
#  'year_built garage_finish',
#  'year_built garage_cars',
#  'year_built garage_area',
#  'year_built garage_qual',
#  'year_built garage_cond',
#  'year_built wood_deck_sf',
#  'year_built open_porch_sf',
#  'year_built enclosed_porch',
#  'year_built 3ssn_porch',
#  'year_built screen_porch',
#  'year_built pool_area',
#  'year_built pool_qc',
#  'year_built fence',
#  'year_built misc_feature',
#  'year_built misc_val',
#  'year_built mo_sold',
#  'year_built yr_sold',
#  'year_built saleprice',
#  'year_remod/add^2',
#  'year_remod/add mas_vnr_type',
#  'year_remod/add mas_vnr_area',
#  'year_remod/add exter_qual',
#  'year_remod/add exter_cond',
#  'year_remod/add bsmt_qual',
#  'year_remod/add bsmt_cond',
#  'year_remod/add bsmt_exposure',
#  'year_remod/add bsmtfin_type_1',
#  'year_remod/add bsmtfin_sf_1',
#  'year_remod/add bsmtfin_type_2',
#  'year_remod/add bsmtfin_sf_2',
#  'year_remod/add bsmt_unf_sf',
#  'year_remod/add total_bsmt_sf',
#  'year_remod/add heating_qc',
#  'year_remod/add central_air',
#  'year_remod/add electrical',
#  'year_remod/add 1st_flr_sf',
#  'year_remod/add 2nd_flr_sf',
#  'year_remod/add low_qual_fin_sf',
#  'year_remod/add gr_liv_area',
#  'year_remod/add bsmt_full_bath',
#  'year_remod/add bsmt_half_bath',
#  'year_remod/add full_bath',
#  'year_remod/add half_bath',
#  'year_remod/add bedroom_abvgr',
#  'year_remod/add kitchen_abvgr',
#  'year_remod/add kitchen_qual',
#  'year_remod/add totrms_abvgrd',
#  'year_remod/add fireplaces',
#  'year_remod/add fireplace_qu',
#  'year_remod/add garage_type',
#  'year_remod/add garage_yr_blt',
#  'year_remod/add garage_finish',
#  'year_remod/add garage_cars',
#  'year_remod/add garage_area',
#  'year_remod/add garage_qual',
#  'year_remod/add garage_cond',
#  'year_remod/add wood_deck_sf',
#  'year_remod/add open_porch_sf',
#  'year_remod/add enclosed_porch',
#  'year_remod/add 3ssn_porch',
#  'year_remod/add screen_porch',
#  'year_remod/add pool_area',
#  'year_remod/add pool_qc',
#  'year_remod/add fence',
#  'year_remod/add misc_feature',
#  'year_remod/add misc_val',
#  'year_remod/add mo_sold',
#  'year_remod/add yr_sold',
#  'year_remod/add saleprice',
#  'mas_vnr_type^2',
#  'mas_vnr_type mas_vnr_area',
#  'mas_vnr_type exter_qual',
#  'mas_vnr_type exter_cond',
#  'mas_vnr_type bsmt_qual',
#  'mas_vnr_type bsmt_cond',
#  'mas_vnr_type bsmt_exposure',
#  'mas_vnr_type bsmtfin_type_1',
#  'mas_vnr_type bsmtfin_sf_1',
#  'mas_vnr_type bsmtfin_type_2',
#  'mas_vnr_type bsmtfin_sf_2',
#  'mas_vnr_type bsmt_unf_sf',
#  'mas_vnr_type total_bsmt_sf',
#  'mas_vnr_type heating_qc',
#  'mas_vnr_type central_air',
#  'mas_vnr_type electrical',
#  'mas_vnr_type 1st_flr_sf',
#  'mas_vnr_type 2nd_flr_sf',
#  'mas_vnr_type low_qual_fin_sf',
#  'mas_vnr_type gr_liv_area',
#  'mas_vnr_type bsmt_full_bath',
#  'mas_vnr_type bsmt_half_bath',
#  'mas_vnr_type full_bath',
#  'mas_vnr_type half_bath',
#  'mas_vnr_type bedroom_abvgr',
#  'mas_vnr_type kitchen_abvgr',
#  'mas_vnr_type kitchen_qual',
#  'mas_vnr_type totrms_abvgrd',
#  'mas_vnr_type fireplaces',
#  'mas_vnr_type fireplace_qu',
#  'mas_vnr_type garage_type',
#  'mas_vnr_type garage_yr_blt',
#  'mas_vnr_type garage_finish',
#  'mas_vnr_type garage_cars',
#  'mas_vnr_type garage_area',
#  'mas_vnr_type garage_qual',
#  'mas_vnr_type garage_cond',
#  'mas_vnr_type wood_deck_sf',
#  'mas_vnr_type open_porch_sf',
#  'mas_vnr_type enclosed_porch',
#  'mas_vnr_type 3ssn_porch',
#  'mas_vnr_type screen_porch',
#  'mas_vnr_type pool_area',
#  'mas_vnr_type pool_qc',
#  'mas_vnr_type fence',
#  'mas_vnr_type misc_feature',
#  'mas_vnr_type misc_val',
#  'mas_vnr_type mo_sold',
#  'mas_vnr_type yr_sold',
#  'mas_vnr_type saleprice',
#  'mas_vnr_area^2',
#  'mas_vnr_area exter_qual',
#  'mas_vnr_area exter_cond',
#  'mas_vnr_area bsmt_qual',
#  'mas_vnr_area bsmt_cond',
#  'mas_vnr_area bsmt_exposure',
#  'mas_vnr_area bsmtfin_type_1',
#  'mas_vnr_area bsmtfin_sf_1',
#  'mas_vnr_area bsmtfin_type_2',
#  'mas_vnr_area bsmtfin_sf_2',
#  'mas_vnr_area bsmt_unf_sf',
#  'mas_vnr_area total_bsmt_sf',
#  'mas_vnr_area heating_qc',
#  'mas_vnr_area central_air',
#  'mas_vnr_area electrical',
#  'mas_vnr_area 1st_flr_sf',
#  'mas_vnr_area 2nd_flr_sf',
#  'mas_vnr_area low_qual_fin_sf',
#  'mas_vnr_area gr_liv_area',
#  'mas_vnr_area bsmt_full_bath',
#  'mas_vnr_area bsmt_half_bath',
#  'mas_vnr_area full_bath',
#  'mas_vnr_area half_bath',
#  'mas_vnr_area bedroom_abvgr',
#  'mas_vnr_area kitchen_abvgr',
#  'mas_vnr_area kitchen_qual',
#  'mas_vnr_area totrms_abvgrd',
#  'mas_vnr_area fireplaces',
#  'mas_vnr_area fireplace_qu',
#  'mas_vnr_area garage_type',
#  'mas_vnr_area garage_yr_blt',
#  'mas_vnr_area garage_finish',
#  'mas_vnr_area garage_cars',
#  'mas_vnr_area garage_area',
#  'mas_vnr_area garage_qual',
#  'mas_vnr_area garage_cond',
#  'mas_vnr_area wood_deck_sf',
#  'mas_vnr_area open_porch_sf',
#  'mas_vnr_area enclosed_porch',
#  'mas_vnr_area 3ssn_porch',
#  'mas_vnr_area screen_porch',
#  'mas_vnr_area pool_area',
#  'mas_vnr_area pool_qc',
#  'mas_vnr_area fence',
#  'mas_vnr_area misc_feature',
#  'mas_vnr_area misc_val',
#  'mas_vnr_area mo_sold',
#  'mas_vnr_area yr_sold',
#  'mas_vnr_area saleprice',
#  'exter_qual^2',
#  'exter_qual exter_cond',
#  'exter_qual bsmt_qual',
#  'exter_qual bsmt_cond',
#  'exter_qual bsmt_exposure',
#  'exter_qual bsmtfin_type_1',
#  'exter_qual bsmtfin_sf_1',
#  'exter_qual bsmtfin_type_2',
#  'exter_qual bsmtfin_sf_2',
#  'exter_qual bsmt_unf_sf',
#  'exter_qual total_bsmt_sf',
#  'exter_qual heating_qc',
#  'exter_qual central_air',
#  'exter_qual electrical',
#  'exter_qual 1st_flr_sf',
#  'exter_qual 2nd_flr_sf',
#  'exter_qual low_qual_fin_sf',
#  'exter_qual gr_liv_area',
#  'exter_qual bsmt_full_bath',
#  'exter_qual bsmt_half_bath',
#  'exter_qual full_bath',
#  'exter_qual half_bath',
#  'exter_qual bedroom_abvgr',
#  'exter_qual kitchen_abvgr',
#  'exter_qual kitchen_qual',
#  'exter_qual totrms_abvgrd',
#  'exter_qual fireplaces',
#  'exter_qual fireplace_qu',
#  'exter_qual garage_type',
#  'exter_qual garage_yr_blt',
#  'exter_qual garage_finish',
#  'exter_qual garage_cars',
#  'exter_qual garage_area',
#  'exter_qual garage_qual',
#  'exter_qual garage_cond',
#  'exter_qual wood_deck_sf',
#  'exter_qual open_porch_sf',
#  'exter_qual enclosed_porch',
#  'exter_qual 3ssn_porch',
#  'exter_qual screen_porch',
#  'exter_qual pool_area',
#  'exter_qual pool_qc',
#  'exter_qual fence',
#  'exter_qual misc_feature',
#  'exter_qual misc_val',
#  'exter_qual mo_sold',
#  'exter_qual yr_sold',
#  'exter_qual saleprice',
#  'exter_cond^2',
#  'exter_cond bsmt_qual',
#  'exter_cond bsmt_cond',
#  'exter_cond bsmt_exposure',
#  'exter_cond bsmtfin_type_1',
#  'exter_cond bsmtfin_sf_1',
#  'exter_cond bsmtfin_type_2',
#  'exter_cond bsmtfin_sf_2',
#  'exter_cond bsmt_unf_sf',
#  'exter_cond total_bsmt_sf',
#  'exter_cond heating_qc',
#  'exter_cond central_air',
#  'exter_cond electrical',
#  'exter_cond 1st_flr_sf',
#  'exter_cond 2nd_flr_sf',
#  'exter_cond low_qual_fin_sf',
#  'exter_cond gr_liv_area',
#  'exter_cond bsmt_full_bath',
#  'exter_cond bsmt_half_bath',
#  'exter_cond full_bath',
#  'exter_cond half_bath',
#  'exter_cond bedroom_abvgr',
#  'exter_cond kitchen_abvgr',
#  'exter_cond kitchen_qual',
#  'exter_cond totrms_abvgrd',
#  'exter_cond fireplaces',
#  'exter_cond fireplace_qu',
#  'exter_cond garage_type',
#  'exter_cond garage_yr_blt',
#  'exter_cond garage_finish',
#  'exter_cond garage_cars',
#  'exter_cond garage_area',
#  'exter_cond garage_qual',
#  'exter_cond garage_cond',
#  'exter_cond wood_deck_sf',
#  'exter_cond open_porch_sf',
#  'exter_cond enclosed_porch',
#  'exter_cond 3ssn_porch',
#  'exter_cond screen_porch',
#  'exter_cond pool_area',
#  'exter_cond pool_qc',
#  'exter_cond fence',
#  'exter_cond misc_feature',
#  'exter_cond misc_val',
#  'exter_cond mo_sold',
#  'exter_cond yr_sold',
#  'exter_cond saleprice',
#  'bsmt_qual^2',
#  'bsmt_qual bsmt_cond',
#  'bsmt_qual bsmt_exposure',
#  'bsmt_qual bsmtfin_type_1',
#  'bsmt_qual bsmtfin_sf_1',
#  'bsmt_qual bsmtfin_type_2',
#  'bsmt_qual bsmtfin_sf_2',
#  'bsmt_qual bsmt_unf_sf',
#  'bsmt_qual total_bsmt_sf',
#  'bsmt_qual heating_qc',
#  'bsmt_qual central_air',
#  'bsmt_qual electrical',
#  'bsmt_qual 1st_flr_sf',
#  'bsmt_qual 2nd_flr_sf',
#  'bsmt_qual low_qual_fin_sf',
#  'bsmt_qual gr_liv_area',
#  'bsmt_qual bsmt_full_bath',
#  'bsmt_qual bsmt_half_bath',
#  'bsmt_qual full_bath',
#  'bsmt_qual half_bath',
#  'bsmt_qual bedroom_abvgr',
#  'bsmt_qual kitchen_abvgr',
#  'bsmt_qual kitchen_qual',
#  'bsmt_qual totrms_abvgrd',
#  'bsmt_qual fireplaces',
#  'bsmt_qual fireplace_qu',
#  'bsmt_qual garage_type',
#  'bsmt_qual garage_yr_blt',
#  'bsmt_qual garage_finish',
#  'bsmt_qual garage_cars',
#  'bsmt_qual garage_area',
#  'bsmt_qual garage_qual',
#  'bsmt_qual garage_cond',
#  'bsmt_qual wood_deck_sf',
#  'bsmt_qual open_porch_sf',
#  'bsmt_qual enclosed_porch',
#  'bsmt_qual 3ssn_porch',
#  'bsmt_qual screen_porch',
#  'bsmt_qual pool_area',
#  'bsmt_qual pool_qc',
#  'bsmt_qual fence',
#  'bsmt_qual misc_feature',
#  'bsmt_qual misc_val',
#  'bsmt_qual mo_sold',
#  'bsmt_qual yr_sold',
#  'bsmt_qual saleprice',
#  'bsmt_cond^2',
#  'bsmt_cond bsmt_exposure',
#  'bsmt_cond bsmtfin_type_1',
#  'bsmt_cond bsmtfin_sf_1',
#  'bsmt_cond bsmtfin_type_2',
#  'bsmt_cond bsmtfin_sf_2',
#  'bsmt_cond bsmt_unf_sf',
#  'bsmt_cond total_bsmt_sf',
#  'bsmt_cond heating_qc',
#  'bsmt_cond central_air',
#  'bsmt_cond electrical',
#  'bsmt_cond 1st_flr_sf',
#  'bsmt_cond 2nd_flr_sf',
#  'bsmt_cond low_qual_fin_sf',
#  'bsmt_cond gr_liv_area',
#  'bsmt_cond bsmt_full_bath',
#  'bsmt_cond bsmt_half_bath',
#  'bsmt_cond full_bath',
#  'bsmt_cond half_bath',
#  'bsmt_cond bedroom_abvgr',
#  'bsmt_cond kitchen_abvgr',
#  'bsmt_cond kitchen_qual',
#  'bsmt_cond totrms_abvgrd',
#  'bsmt_cond fireplaces',
#  'bsmt_cond fireplace_qu',
#  'bsmt_cond garage_type',
#  'bsmt_cond garage_yr_blt',
#  'bsmt_cond garage_finish',
#  'bsmt_cond garage_cars',
#  'bsmt_cond garage_area',
#  'bsmt_cond garage_qual',
#  'bsmt_cond garage_cond',
#  'bsmt_cond wood_deck_sf',
#  'bsmt_cond open_porch_sf',
#  'bsmt_cond enclosed_porch',
#  'bsmt_cond 3ssn_porch',
#  'bsmt_cond screen_porch',
#  'bsmt_cond pool_area',
#  'bsmt_cond pool_qc',
#  'bsmt_cond fence',
#  'bsmt_cond misc_feature',
#  'bsmt_cond misc_val',
#  'bsmt_cond mo_sold',
#  'bsmt_cond yr_sold',
#  'bsmt_cond saleprice',
#  'bsmt_exposure^2',
#  'bsmt_exposure bsmtfin_type_1',
#  'bsmt_exposure bsmtfin_sf_1',
#  'bsmt_exposure bsmtfin_type_2',
#  'bsmt_exposure bsmtfin_sf_2',
#  'bsmt_exposure bsmt_unf_sf',
#  'bsmt_exposure total_bsmt_sf',
#  'bsmt_exposure heating_qc',
#  'bsmt_exposure central_air',
#  'bsmt_exposure electrical',
#  'bsmt_exposure 1st_flr_sf',
#  'bsmt_exposure 2nd_flr_sf',
#  'bsmt_exposure low_qual_fin_sf',
#  'bsmt_exposure gr_liv_area',
#  'bsmt_exposure bsmt_full_bath',
#  'bsmt_exposure bsmt_half_bath',
#  'bsmt_exposure full_bath',
#  'bsmt_exposure half_bath',
#  'bsmt_exposure bedroom_abvgr',
#  'bsmt_exposure kitchen_abvgr',
#  'bsmt_exposure kitchen_qual',
#  'bsmt_exposure totrms_abvgrd',
#  'bsmt_exposure fireplaces',
#  'bsmt_exposure fireplace_qu',
#  'bsmt_exposure garage_type',
#  'bsmt_exposure garage_yr_blt',
#  'bsmt_exposure garage_finish',
#  'bsmt_exposure garage_cars',
#  'bsmt_exposure garage_area',
#  'bsmt_exposure garage_qual',
#  'bsmt_exposure garage_cond',
#  'bsmt_exposure wood_deck_sf',
#  'bsmt_exposure open_porch_sf',
#  'bsmt_exposure enclosed_porch',
#  'bsmt_exposure 3ssn_porch',
#  'bsmt_exposure screen_porch',
#  'bsmt_exposure pool_area',
#  'bsmt_exposure pool_qc',
#  'bsmt_exposure fence',
#  'bsmt_exposure misc_feature',
#  'bsmt_exposure misc_val',
#  'bsmt_exposure mo_sold',
#  'bsmt_exposure yr_sold',
#  'bsmt_exposure saleprice',
#  'bsmtfin_type_1^2',
#  'bsmtfin_type_1 bsmtfin_sf_1',
#  'bsmtfin_type_1 bsmtfin_type_2',
#  'bsmtfin_type_1 bsmtfin_sf_2',
#  'bsmtfin_type_1 bsmt_unf_sf',
#  'bsmtfin_type_1 total_bsmt_sf',
#  'bsmtfin_type_1 heating_qc',
#  'bsmtfin_type_1 central_air',
#  'bsmtfin_type_1 electrical',
#  'bsmtfin_type_1 1st_flr_sf',
#  'bsmtfin_type_1 2nd_flr_sf',
#  'bsmtfin_type_1 low_qual_fin_sf',
#  'bsmtfin_type_1 gr_liv_area',
#  'bsmtfin_type_1 bsmt_full_bath',
#  'bsmtfin_type_1 bsmt_half_bath',
#  'bsmtfin_type_1 full_bath',
#  'bsmtfin_type_1 half_bath',
#  'bsmtfin_type_1 bedroom_abvgr',
#  'bsmtfin_type_1 kitchen_abvgr',
#  'bsmtfin_type_1 kitchen_qual',
#  'bsmtfin_type_1 totrms_abvgrd',
#  'bsmtfin_type_1 fireplaces',
#  'bsmtfin_type_1 fireplace_qu',
#  'bsmtfin_type_1 garage_type',
#  'bsmtfin_type_1 garage_yr_blt',
#  'bsmtfin_type_1 garage_finish',
#  'bsmtfin_type_1 garage_cars',
#  'bsmtfin_type_1 garage_area',
#  'bsmtfin_type_1 garage_qual',
#  'bsmtfin_type_1 garage_cond',
#  'bsmtfin_type_1 wood_deck_sf',
#  'bsmtfin_type_1 open_porch_sf',
#  'bsmtfin_type_1 enclosed_porch',
#  'bsmtfin_type_1 3ssn_porch',
#  'bsmtfin_type_1 screen_porch',
#  'bsmtfin_type_1 pool_area',
#  'bsmtfin_type_1 pool_qc',
#  'bsmtfin_type_1 fence',
#  'bsmtfin_type_1 misc_feature',
#  'bsmtfin_type_1 misc_val',
#  'bsmtfin_type_1 mo_sold',
#  'bsmtfin_type_1 yr_sold',
#  'bsmtfin_type_1 saleprice',
#  'bsmtfin_sf_1^2',
#  'bsmtfin_sf_1 bsmtfin_type_2',
#  'bsmtfin_sf_1 bsmtfin_sf_2',
#  'bsmtfin_sf_1 bsmt_unf_sf',
#  'bsmtfin_sf_1 total_bsmt_sf',
#  'bsmtfin_sf_1 heating_qc',
#  'bsmtfin_sf_1 central_air',
#  'bsmtfin_sf_1 electrical',
#  'bsmtfin_sf_1 1st_flr_sf',
#  'bsmtfin_sf_1 2nd_flr_sf',
#  'bsmtfin_sf_1 low_qual_fin_sf',
#  'bsmtfin_sf_1 gr_liv_area',
#  'bsmtfin_sf_1 bsmt_full_bath',
#  ...]

# %%
# view X_poly in a DataFrame
poly_df = pd.DataFrame(X_poly, columns=poly.get_feature_names(features))

# %%
# creating a dataframe with all polynomial features and correlation with 'saleprice'
poly_corr = poly_df.corr()[['saleprice']].abs().sort_values(['saleprice'], ascending=False).head(50)

# %%
poly_corr
# Out:
#                              saleprice
# saleprice                     1.000000
# yr_sold saleprice             0.999999
# year_remod/add saleprice      0.999861
# garage_yr_blt saleprice       0.999773
# year_built saleprice          0.999655
# electrical saleprice          0.990981
# overall_qual saleprice        0.978457
# exter_qual saleprice          0.971390
# kitchen_qual saleprice        0.971069
# exter_cond saleprice          0.965553
# bsmt_qual saleprice           0.963907
# saleprice^2                   0.960533
# bsmt_cond saleprice           0.957398
# garage_cond saleprice         0.954633
# central_air saleprice         0.954302
# heating_qc saleprice          0.953929
# garage_qual saleprice         0.951071
# gr_liv_area saleprice         0.939922
# garage_cars saleprice         0.939210
# kitchen_abvgr saleprice       0.935240
# totrms_abvgrd saleprice       0.929487
# 1st_flr_sf saleprice          0.925962
# garage_area saleprice         0.923439
# total_bsmt_sf saleprice       0.914975
# full_bath saleprice           0.914489
# overall_cond saleprice        0.907024
# garage_finish saleprice       0.886283
# lot_frontage saleprice        0.875509
# overall_qual gr_liv_area      0.872198
# exter_qual gr_liv_area        0.853728
# garage_type saleprice         0.853103
# gr_liv_area kitchen_qual      0.845539
# bsmt_qual gr_liv_area         0.844279
# overall_qual 1st_flr_sf       0.840806
# overall_qual kitchen_qual     0.838665
# overall_qual exter_qual       0.834606
# overall_qual^2                0.831658
# overall_qual total_bsmt_sf    0.829780
# overall_qual garage_area      0.827483
# overall_qual garage_cars      0.825071
# total_bsmt_sf gr_liv_area     0.824710
# fireplace_qu saleprice        0.821122
# bedroom_abvgr saleprice       0.820561
# overall_qual bsmt_qual        0.819301
# overall_qual year_built       0.811202
# overall_qual garage_yr_blt    0.809525
# overall_qual totrms_abvgrd    0.809152
# gr_liv_area garage_area       0.809005
# overall_qual year_remod/add   0.808999
# gr_liv_area garage_cars       0.807166

# %% [markdown]
# #### Creating Features with Correlations > .8

# %%
# filtering new dataframe to include highest correlated variables that are not rengineered using saleprice
new_features_eng = poly_corr.loc[(poly_corr['saleprice'] >= .8) & (poly_corr['saleprice'] <.875)]
new_features_eng
# Out:
#                              saleprice
# overall_qual gr_liv_area      0.872198
# exter_qual gr_liv_area        0.853728
# garage_type saleprice         0.853103
# gr_liv_area kitchen_qual      0.845539
# bsmt_qual gr_liv_area         0.844279
# overall_qual 1st_flr_sf       0.840806
# overall_qual kitchen_qual     0.838665
# overall_qual exter_qual       0.834606
# overall_qual^2                0.831658
# overall_qual total_bsmt_sf    0.829780
# overall_qual garage_area      0.827483
# overall_qual garage_cars      0.825071
# total_bsmt_sf gr_liv_area     0.824710
# fireplace_qu saleprice        0.821122
# bedroom_abvgr saleprice       0.820561
# overall_qual bsmt_qual        0.819301
# overall_qual year_built       0.811202
# overall_qual garage_yr_blt    0.809525
# overall_qual totrms_abvgrd    0.809152
# gr_liv_area garage_area       0.809005
# overall_qual year_remod/add   0.808999
# gr_liv_area garage_cars       0.807166

# %%
new_features_eng.index
# Out:
# Index(['overall_qual gr_liv_area', 'exter_qual gr_liv_area',
#        'garage_type saleprice', 'gr_liv_area kitchen_qual',
#        'bsmt_qual gr_liv_area', 'overall_qual 1st_flr_sf',
#        'overall_qual kitchen_qual', 'overall_qual exter_qual',
#        'overall_qual^2', 'overall_qual total_bsmt_sf',
#        'overall_qual garage_area', 'overall_qual garage_cars',
#        'total_bsmt_sf gr_liv_area', 'fireplace_qu saleprice',
#        'bedroom_abvgr saleprice', 'overall_qual bsmt_qual',
#        'overall_qual year_built', 'overall_qual garage_yr_blt',
#        'overall_qual totrms_abvgrd', 'gr_liv_area garage_area',
#        'overall_qual year_remod/add', 'gr_liv_area garage_cars'],
#       dtype='object')

# %%
# adding features above to the dataframe: excluding features with saleprice and 
for i in new_features_eng.index:
    try:
        x, y = i.split(' ')
        if y == 'saleprice':
            continue
        else:
            df[x + ' * ' + y] = df[x] * df[y]
    except:
        df[i] = df[i[:len(i)-2]] * df[i[:len(i)-2]]

# %% [markdown]
# ### Checking Correlation for Interactions Created

# %%
# newly engineered variables
final_eng = df.columns[81:].values
final_eng
# Out:
# array(['garage_area * garage_cars', 'totrms_abvgrd * gr_liv_area',
#        '1st_flr_sf * total_bsmt_sf', 'garage_yr_blt * year_built',
#        'total_area', 'overall_qual * gr_liv_area',
#        'exter_qual * gr_liv_area', 'gr_liv_area * kitchen_qual',
#        'bsmt_qual * gr_liv_area', 'overall_qual * 1st_flr_sf',
#        'overall_qual * kitchen_qual', 'overall_qual * exter_qual',
#        'overall_qual^2', 'overall_qual * total_bsmt_sf',
#        'overall_qual * garage_area', 'overall_qual * garage_cars',
#        'total_bsmt_sf * gr_liv_area', 'overall_qual * bsmt_qual',
#        'overall_qual * year_built', 'overall_qual * garage_yr_blt',
#        'overall_qual * totrms_abvgrd', 'gr_liv_area * garage_area',
#        'overall_qual * year_remod/add', 'gr_liv_area * garage_cars'],
#       dtype=object)

# %%
# adding 'saleprice' to check correlation
final_eng_saleprice = df.columns[80:].values

# %%
# checking correlations of newly engeneered variables
df[final_eng_saleprice].corr()['saleprice']
# Out:
# saleprice                        1.000000
# garage_area * garage_cars        0.705718
# totrms_abvgrd * gr_liv_area      0.649710
# 1st_flr_sf * total_bsmt_sf       0.702681
# garage_yr_blt * year_built       0.583546
# total_area                       0.839866
# overall_qual * gr_liv_area       0.872198
# exter_qual * gr_liv_area         0.853728
# gr_liv_area * kitchen_qual       0.845539
# bsmt_qual * gr_liv_area          0.844279
# overall_qual * 1st_flr_sf        0.840806
# overall_qual * kitchen_qual      0.838665
# overall_qual * exter_qual        0.834606
# overall_qual^2                   0.831658
# overall_qual * total_bsmt_sf     0.829780
# overall_qual * garage_area       0.827483
# overall_qual * garage_cars       0.825071
# total_bsmt_sf * gr_liv_area      0.824710
# overall_qual * bsmt_qual         0.819301
# overall_qual * year_built        0.811202
# overall_qual * garage_yr_blt     0.809525
# overall_qual * totrms_abvgrd     0.809152
# gr_liv_area * garage_area        0.809005
# overall_qual * year_remod/add    0.808999
# gr_liv_area * garage_cars        0.807166
# Name: saleprice, dtype: float64

# %% [markdown]
# ### Boxplots for Nominal Variables

# %%
# defining a function to create boxplot for nominal variables
def subplot_boxplots(dataframe, list_of_columns):
      
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows,
                           ncols=2,
                           figsize=(15, 5 * nrows))
    plt.tight_layout(pad=4)
    ax = ax.ravel() 
    
    for index, column in enumerate(list_of_columns):
        
        sns.boxplot(x=dataframe[column], y=dataframe['saleprice'] ,ax=ax[index])
        ax[index].set_title(list_of_columns[index], size=14)
        ax[index].set_xlabel(list_of_columns[index], size=13)
        ax[index].set_ylabel('saleprice', size=13)

# %%
# plotting boxplots to look for nominal variables to be 'dummied'
subplot_boxplots(df, nominal_variables.columns)

# %% [markdown]
# ### Creating Dummy Variables ( Qualitative )
# > #### Variables with High Variation on Price

# %%
# creating a list of the variables to be dummied - chosen by analyzing boxplots
dummies_list = ['ms_zoning', 'condition_1', 'condition_2',
                'neighborhood', 'exterior_1st', 'exterior_2nd', 'sale_type']

# %%
# creating function to generate dummies for selected variables
def create_dummies(dataframe, dummies_list):
    dataframe = pd.get_dummies(dataframe, columns=dummies_list, drop_first=True)
    return dataframe

# %%
# add dummies to dataframe
df = create_dummies(df, dummies_list)

# %%
# printing all dummies created
dummies = df.columns[81:]
dummies.values
# Out:
# array(['gr_liv_area * kitchen_qual', 'bsmt_qual * gr_liv_area',
#        'overall_qual * 1st_flr_sf', 'overall_qual * kitchen_qual',
#        'overall_qual * exter_qual', 'overall_qual^2',
#        'overall_qual * total_bsmt_sf', 'overall_qual * garage_area',
#        'overall_qual * garage_cars', 'total_bsmt_sf * gr_liv_area',
#        'overall_qual * bsmt_qual', 'overall_qual * year_built',
#        'overall_qual * garage_yr_blt', 'overall_qual * totrms_abvgrd',
#        'gr_liv_area * garage_area', 'overall_qual * year_remod/add',
#        'gr_liv_area * garage_cars', 'ms_zoning_C (all)', 'ms_zoning_FV',
#        'ms_zoning_I (all)', 'ms_zoning_RH', 'ms_zoning_RL',
#        'ms_zoning_RM', 'condition_1_Feedr', 'condition_1_Norm',
#        'condition_1_PosA', 'condition_1_PosN', 'condition_1_RRAe',
#        'condition_1_RRAn', 'condition_1_RRNe', 'condition_1_RRNn',
#        'condition_2_Feedr', 'condition_2_Norm', 'condition_2_PosA',
#        'condition_2_PosN', 'condition_2_RRAe', 'condition_2_RRAn',
#        'condition_2_RRNn', 'neighborhood_Blueste', 'neighborhood_BrDale',
#        'neighborhood_BrkSide', 'neighborhood_ClearCr',
#        'neighborhood_CollgCr', 'neighborhood_Crawfor',
#        'neighborhood_Edwards', 'neighborhood_Gilbert',
#        'neighborhood_Greens', 'neighborhood_GrnHill',
#        'neighborhood_IDOTRR', 'neighborhood_Landmrk',
#        'neighborhood_MeadowV', 'neighborhood_Mitchel',
#        'neighborhood_NAmes', 'neighborhood_NPkVill',
#        'neighborhood_NWAmes', 'neighborhood_NoRidge',
#        'neighborhood_NridgHt', 'neighborhood_OldTown',
#        'neighborhood_SWISU', 'neighborhood_Sawyer',
#        'neighborhood_SawyerW', 'neighborhood_Somerst',
#        'neighborhood_StoneBr', 'neighborhood_Timber',
#        'neighborhood_Veenker', 'exterior_1st_AsphShn',
#        'exterior_1st_BrkComm', 'exterior_1st_BrkFace',
#        'exterior_1st_CBlock', 'exterior_1st_CemntBd',
#        'exterior_1st_HdBoard', 'exterior_1st_ImStucc',
#        'exterior_1st_MetalSd', 'exterior_1st_Plywood',
#        'exterior_1st_Stone', 'exterior_1st_Stucco',
#        'exterior_1st_VinylSd', 'exterior_1st_Wd Sdng',
#        'exterior_1st_WdShing', 'exterior_2nd_AsphShn',
#        'exterior_2nd_Brk Cmn', 'exterior_2nd_BrkFace',
#        'exterior_2nd_CBlock', 'exterior_2nd_CmentBd',
#        'exterior_2nd_HdBoard', 'exterior_2nd_ImStucc',
#        'exterior_2nd_MetalSd', 'exterior_2nd_Plywood',
#        'exterior_2nd_Stone', 'exterior_2nd_Stucco',
#        'exterior_2nd_VinylSd', 'exterior_2nd_Wd Sdng',
#        'exterior_2nd_Wd Shng', 'sale_type_CWD', 'sale_type_Con',
#        'sale_type_ConLD', 'sale_type_ConLI', 'sale_type_ConLw',
#        'sale_type_New', 'sale_type_Oth', 'sale_type_WD '], dtype=object)

# %%
# creating a list for all the features
features = list(strong_correlations)

# %%
# adding all engineered features to the features list
for i in final_eng:
    features.append(i)

# %%
# adding the dummies created to the features list
for i in dummies.values:
    features.append(i)

# %%
features
# Out:
# ['overall_qual',
#  'exter_qual',
#  'gr_liv_area',
#  'kitchen_qual',
#  'garage_area',
#  'garage_cars',
#  'total_bsmt_sf',
#  '1st_flr_sf',
#  'bsmt_qual',
#  'year_built',
#  'garage_finish',
#  'year_remod/add',
#  'fireplace_qu',
#  'full_bath',
#  'garage_yr_blt',
#  'totrms_abvgrd',
#  'mas_vnr_area',
#  'garage_area * garage_cars',
#  'totrms_abvgrd * gr_liv_area',
#  '1st_flr_sf * total_bsmt_sf',
#  'garage_yr_blt * year_built',
#  'total_area',
#  'overall_qual * gr_liv_area',
#  'exter_qual * gr_liv_area',
#  'gr_liv_area * kitchen_qual',
#  'bsmt_qual * gr_liv_area',
#  'overall_qual * 1st_flr_sf',
#  'overall_qual * kitchen_qual',
#  'overall_qual * exter_qual',
#  'overall_qual^2',
#  'overall_qual * total_bsmt_sf',
#  'overall_qual * garage_area',
#  'overall_qual * garage_cars',
#  'total_bsmt_sf * gr_liv_area',
#  'overall_qual * bsmt_qual',
#  'overall_qual * year_built',
#  'overall_qual * garage_yr_blt',
#  'overall_qual * totrms_abvgrd',
#  'gr_liv_area * garage_area',
#  'overall_qual * year_remod/add',
#  'gr_liv_area * garage_cars',
#  'gr_liv_area * kitchen_qual',
#  'bsmt_qual * gr_liv_area',
#  'overall_qual * 1st_flr_sf',
#  'overall_qual * kitchen_qual',
#  'overall_qual * exter_qual',
#  'overall_qual^2',
#  'overall_qual * total_bsmt_sf',
#  'overall_qual * garage_area',
#  'overall_qual * garage_cars',
#  'total_bsmt_sf * gr_liv_area',
#  'overall_qual * bsmt_qual',
#  'overall_qual * year_built',
#  'overall_qual * garage_yr_blt',
#  'overall_qual * totrms_abvgrd',
#  'gr_liv_area * garage_area',
#  'overall_qual * year_remod/add',
#  'gr_liv_area * garage_cars',
#  'ms_zoning_C (all)',
#  'ms_zoning_FV',
#  'ms_zoning_I (all)',
#  'ms_zoning_RH',
#  'ms_zoning_RL',
#  'ms_zoning_RM',
#  'condition_1_Feedr',
#  'condition_1_Norm',
#  'condition_1_PosA',
#  'condition_1_PosN',
#  'condition_1_RRAe',
#  'condition_1_RRAn',
#  'condition_1_RRNe',
#  'condition_1_RRNn',
#  'condition_2_Feedr',
#  'condition_2_Norm',
#  'condition_2_PosA',
#  'condition_2_PosN',
#  'condition_2_RRAe',
#  'condition_2_RRAn',
#  'condition_2_RRNn',
#  'neighborhood_Blueste',
#  'neighborhood_BrDale',
#  'neighborhood_BrkSide',
#  'neighborhood_ClearCr',
#  'neighborhood_CollgCr',
#  'neighborhood_Crawfor',
#  'neighborhood_Edwards',
#  'neighborhood_Gilbert',
#  'neighborhood_Greens',
#  'neighborhood_GrnHill',
#  'neighborhood_IDOTRR',
#  'neighborhood_Landmrk',
#  'neighborhood_MeadowV',
#  'neighborhood_Mitchel',
#  'neighborhood_NAmes',
#  'neighborhood_NPkVill',
#  'neighborhood_NWAmes',
#  'neighborhood_NoRidge',
#  'neighborhood_NridgHt',
#  'neighborhood_OldTown',
#  'neighborhood_SWISU',
#  'neighborhood_Sawyer',
#  'neighborhood_SawyerW',
#  'neighborhood_Somerst',
#  'neighborhood_StoneBr',
#  'neighborhood_Timber',
#  'neighborhood_Veenker',
#  'exterior_1st_AsphShn',
#  'exterior_1st_BrkComm',
#  'exterior_1st_BrkFace',
#  'exterior_1st_CBlock',
#  'exterior_1st_CemntBd',
#  'exterior_1st_HdBoard',
#  'exterior_1st_ImStucc',
#  'exterior_1st_MetalSd',
#  'exterior_1st_Plywood',
#  'exterior_1st_Stone',
#  'exterior_1st_Stucco',
#  'exterior_1st_VinylSd',
#  'exterior_1st_Wd Sdng',
#  'exterior_1st_WdShing',
#  'exterior_2nd_AsphShn',
#  'exterior_2nd_Brk Cmn',
#  'exterior_2nd_BrkFace',
#  'exterior_2nd_CBlock',
#  'exterior_2nd_CmentBd',
#  'exterior_2nd_HdBoard',
#  'exterior_2nd_ImStucc',
#  'exterior_2nd_MetalSd',
#  'exterior_2nd_Plywood',
#  'exterior_2nd_Stone',
#  'exterior_2nd_Stucco',
#  'exterior_2nd_VinylSd',
#  'exterior_2nd_Wd Sdng',
#  'exterior_2nd_Wd Shng',
#  'sale_type_CWD',
#  'sale_type_Con',
#  'sale_type_ConLD',
#  'sale_type_ConLI',
#  'sale_type_ConLw',
#  'sale_type_New',
#  'sale_type_Oth',
#  'sale_type_WD ']

# %%
print(len(df.columns))
# Out:
# 182

# %%
# saving clean dataframe with created columns
df.to_csv('../datasets/train_clean.csv', index_label=False)

# %% [markdown]
# ## Same with test data! from Kaggle

# %%
# reading train dataset into memmory
df = pd.read_csv('../datasets/test.csv')

# %%
# changing the column names to lower and underscores
df.columns = [column.lower().replace(' ','_') for column in df.columns]

# %%
# checking for null values
df.isnull().mean()[df.isnull().mean() > 0].sort_values(ascending=False)
# Out:
# pool_qc           0.995449
# misc_feature      0.953356
# alley             0.934016
# fence             0.804323
# fireplace_qu      0.480091
# lot_frontage      0.182025
# garage_yr_blt     0.051195
# garage_finish     0.051195
# garage_qual       0.051195
# garage_cond       0.051195
# garage_type       0.050057
# bsmtfin_type_2    0.028441
# bsmtfin_type_1    0.028441
# bsmt_exposure     0.028441
# bsmt_cond         0.028441
# bsmt_qual         0.028441
# mas_vnr_area      0.001138
# mas_vnr_type      0.001138
# electrical        0.001138
# dtype: float64

# %%
# transform columns to numerical - This will fix some null values as well!

qualitative_to_numeric_dict = {'pool_qc': {'Ex': 5, 
                                           'Gd': 4,
                                           'TA': 3,
                                           'Fa': 2,
                                            np.nan: 0},
                               'misc_feature': {'Elev': 5,
                                                'Gar2': 4,
                                                'Othr': 3,
                                                'Shed': 2,
                                                'TenC': 1,
                                                 np.nan: 0},
                               'alley': {'Grvl': 2,
                                         'Pave': 1,
                                          np.nan: 0},
                               'fence': {'GdPrv': 4,
                                         'MnPrv': 3,
                                         'GdWo': 2,
                                         'MnWw': 1,
                                          np.nan: 0},
                               'fireplace_qu': {'Ex': 5, 
                                                'Gd': 4,
                                                'TA': 3,
                                                'Fa': 2,
                                                'Po': 1,
                                                 np.nan: 0},
                               'garage_cond': {'Ex': 5, 
                                               'Gd': 4,
                                               'TA': 3,
                                               'Fa': 2,
                                               'Po': 1,
                                                np.nan: 0},
                               'garage_qual': {'Ex': 5, 
                                               'Gd': 4,
                                               'TA': 3,
                                               'Fa': 2,
                                               'Po': 1,
                                                np.nan: 0},
                               'garage_finish': {'Fin': 3,
                                                 'RFn': 2,
                                                 'Unf': 1,
                                                 np.nan: 0},
                               'garage_type': {'2Types': 6,
                                               'Attchd': 5,
                                               'Basment': 4,
                                               'BuiltIn': 3,
                                               'CarPort': 2,
                                               'Detchd': 1,
                                                np.nan: 0},
                               'bsmt_exposure': {'Gd': 4,
                                                 'Av': 3,
                                                 'Mn': 2,
                                                 'No': 1,
                                                  np.nan: 0},
                               'bsmtfin_type_2': {'GLQ': 6,
                                                  'ALQ': 5,
                                                  'BLQ': 4,
                                                  'Rec': 3,
                                                  'LwQ': 2,
                                                  'Unf': 1,
                                                   np.nan: 0},
                               'bsmt_cond': {'Ex': 5, 
                                             'Gd': 4,
                                             'TA': 3,
                                             'Fa': 2,
                                             'Po': 1,
                                              np.nan: 0},
                               'bsmt_qual': {'Ex': 5, 
                                             'Gd': 4,
                                             'TA': 3,
                                             'Fa': 2,
                                             'Po': 1,
                                              np.nan: 0},
                               'bsmtfin_type_1': {'GLQ': 6,
                                                  'ALQ': 5,
                                                  'BLQ': 4,
                                                  'Rec': 3,
                                                  'LwQ': 2,
                                                  'Unf': 1,
                                                   np.nan: 0},
                               'mas_vnr_type': {'BrkCmn': 4,
                                                'BrkFace': 3,
                                                'CBlock': 2,
                                                'None': 0,
                                                 np.nan: 0,
                                                'Stone': 1},
                               'exter_qual': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'exter_cond': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'heating_qc': {'Ex': 5, 
                                              'Gd': 4,
                                              'TA': 3,
                                              'Fa': 2,
                                              'Po': 1},
                               'central_air': {'Y': 1, 
                                               'N': 0},
                               'kitchen_qual': {'Ex': 5, 
                                                'Gd': 4,
                                                'TA': 3,
                                                'Fa': 2,
                                                'Po': 1},
                               'electrical': {'SBrkr': 4,
                                              'FuseA': 3,
                                              'FuseF': 2,
                                              'FuseP': 1,
                                              'Mix': 0}
                              }

# %%
# replace qualitative values by a range of integers
df.replace(qualitative_to_numeric_dict, inplace=True)

# %%
# checking for null columns again as see what is left
df.isnull().mean()[df.isnull().mean() > 0].sort_values(ascending=False)
# Out:
# lot_frontage     0.182025
# garage_yr_blt    0.051195
# electrical       0.001138
# mas_vnr_area     0.001138
# dtype: float64

# %%
# list of columns with null values
null_columns = [column for column in df.columns if df[column].isnull().sum() > 0]

# %%
null_columns
# Out:
# ['lot_frontage', 'mas_vnr_area', 'electrical', 'garage_yr_blt']

# %%
# fill null values with the mean() for columns with higher correlation with 'saleprice'
df['mas_vnr_area'].fillna(df['mas_vnr_area'].median(), inplace=True)
df['garage_yr_blt'].fillna(df['garage_yr_blt'].median(), inplace=True)
df['lot_frontage'].fillna(df['lot_frontage'].median(), inplace=True)
df['electrical'].fillna(df['electrical'].median(), inplace=True)

# %%
# checking for duplicated values
df.duplicated().mean()
# Out:
# 0.0

# %%
# create an interaction term between strongly correlated variables
df['garage_area * garage_cars'] = df['garage_area'] * df['garage_cars']

# create an interaction term between strongly correlated variables
df['totrms_abvgrd * gr_liv_area'] = df['totrms_abvgrd'] * df['gr_liv_area']

# create an interaction term between strongly correlated variables
df['1st_flr_sf * total_bsmt_sf'] = df['1st_flr_sf'] * df['total_bsmt_sf']

# create an interaction term between strongly correlated variables
df['garage_yr_blt * year_built'] = df['garage_yr_blt'] * df['year_built']

# %%
# creating df['total_area']
df['total_area'] = df['total_bsmt_sf'] + df['1st_flr_sf'] + df['2nd_flr_sf'] \
                   + df['gr_liv_area'] + df['garage_area']

# %%
# adding features above to the dataframe: excluding features with saleprice and 
for i in new_features_eng.index:
    try:
        x, y = i.split(' ')
        if y == 'saleprice':
            continue
        else:
            df[x + ' * ' + y] = df[x] * df[y]
    except:
        df[i] = df[i[:len(i)-2]] * df[i[:len(i)-2]]

# %%
# creating dummies
df = create_dummies(df, dummies_list)

# %%
# inputting 0 for columns that do not exist on test set
for feature in features:
    if feature not in df.columns:
        df[feature] = 0
print(len(df.columns))
# Out:
# 185

# %%
# saving clean dataframe
df.to_csv('../datasets/test_clean.csv', index_label=False)
